# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
import os
import cv2
import pandas as pd 
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt 
import tensorflow as tf 
import keras 
from sklearn.metrics import confusion_matrix, classification_report, ConfusionMatrixDisplay
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.optimizers import Adam, Adamax
from sklearn.utils import shuffle
from sklearn.model_selection import train_test_split
from tqdm import tqdm
import warnings
warnings.filterwarnings("ignore")

# %%
import os, random, numpy as np, tensorflow as tf
seed = 42
os.environ['PYTHONHASHSEED'] = str(seed)
random.seed(seed)
np.random.seed(seed)
tf.random.set_seed(seed)

# %%
# !pip install kagglehub -q
import kagglehub

# Download latest version
path = kagglehub.dataset_download("ahmedismaiil/skin-issues-version-2-dataset-balanced")

print("Path to dataset files:", path)

files = os.listdir(path)
print("Files in the dataset directory:", files)
# Out:
# Path to dataset files: /kaggle/input/skin-issues-version-2-dataset-balanced
# Files in the dataset directory: ['Skin v2']

# %%
Class_Names = os.listdir(os.path.join(path, 'Skin v2'))
Class_Names_dict = {name: idx for idx, name in enumerate(Class_Names)}
print("Class Mapping:", Class_Names_dict)

IMAGE_SIZE = (256, 256)
BATCH_SIZE = 32
CHANNELS = 3
# Out:
# Class Mapping: {'acne': 0, 'dark spots': 1, 'wrinkles': 2, 'pores': 3, 'blackheades': 4}

# %%
def load_data(data_dir):
    Images = []
    Labels = []
    for folder in os.listdir(data_dir):
        print(f"Loading images from '{folder}' folder...")
        for img in tqdm(os.listdir(os.path.join(data_dir, folder))):
            img_path = os.path.join(data_dir, folder, img)
            image = cv2.imread(img_path)
            image = cv2.resize(image, IMAGE_SIZE)
            image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
            Images.append(image)
            Labels.append(Class_Names_dict[folder])
    
    Images = np.array(Images, dtype='float32')
    Labels = np.array(Labels, dtype='int64')
    return Images, Labels

Images, Labels = load_data(os.path.join(path, 'Skin v2'))
Images, Labels = shuffle(Images, Labels, random_state=42)

print(f"\n✅ Total Images: {Images.shape[0]}")
print(f"✅ Image Size: {Images.shape[1:]}")

for i, cls in enumerate(Class_Names):
    print(f"Number of {cls} images: {len(Labels[Labels == i])}")
# Out:
# Loading images from 'acne' folder...
# 100%|██████████| 2060/2060 [00:16<00:00, 121.79it/s]
# Loading images from 'dark spots' folder...
# 100%|██████████| 2126/2126 [00:23<00:00, 92.07it/s]
# Loading images from 'wrinkles' folder...
# 100%|██████████| 1982/1982 [00:18<00:00, 109.15it/s]
# Loading images from 'pores' folder...
# 100%|██████████| 1632/1632 [00:14<00:00, 111.96it/s]
# Loading images from 'blackheades' folder...
# 100%|██████████| 1970/1970 [00:16<00:00, 119.26it/s]
# ✅ Total Images: 9770
# ✅ Image Size: (256, 256, 3)
# Number of acne images: 2060
# Number of dark spots images: 2126
# Number of wrinkles images: 1982
# Number of pores images: 1632
# Number of blackheades images: 1970

# %%
Train_Images, dummy_Images, Train_Labels, dummy_Labels = train_test_split(
    Images, Labels, test_size=0.3, random_state=42, stratify=Labels
)
Val_Images, Test_Images, Val_Labels, Test_Labels = train_test_split(
    dummy_Images, dummy_Labels, test_size=0.5, random_state=42, stratify=dummy_Labels
)

_, train_counts = np.unique(Train_Labels, return_counts=True)
_, val_counts = np.unique(Val_Labels, return_counts=True)
_, test_counts = np.unique(Test_Labels, return_counts=True)

df = pd.DataFrame({'Train': train_counts, 'Validation': val_counts, 'Test': test_counts}, index=Class_Names)
print("\n Dataset Distribution:")
print(df)
# Out:
#  Dataset Distribution:
#              Train  Validation  Test
# acne          1442         309   309
# dark spots    1488         319   319
# wrinkles      1387         297   298
# pores         1143         245   244
# blackheades   1379         295   296

# %%
from tensorflow.keras.utils import to_categorical

# One-hot encoding
Train_Labels_cat = to_categorical(Train_Labels, num_classes=len(Class_Names))
Val_Labels_cat = to_categorical(Val_Labels, num_classes=len(Class_Names))
Test_Labels_cat = to_categorical(Test_Labels, num_classes=len(Class_Names))

train_datagen = ImageDataGenerator(
    rescale=1./255,
    rotation_range=20,
    zoom_range=0.2,
    horizontal_flip=True
)
val_datagen = ImageDataGenerator(rescale=1./255)
test_datagen = ImageDataGenerator(rescale=1./255)

# Use .flow() for numpy arrays
train_generator = train_datagen.flow(Train_Images, Train_Labels_cat, batch_size=BATCH_SIZE, shuffle=True)
val_generator = val_datagen.flow(Val_Images, Val_Labels_cat, batch_size=BATCH_SIZE, shuffle=False)
test_generator = test_datagen.flow(Test_Images, Test_Labels_cat, batch_size=BATCH_SIZE, shuffle=False)

# %% [markdown]
# **VGG16**

# %%
from tensorflow.keras.applications import VGG16
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Flatten, Dense, Dropout, BatchNormalization
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau

# %%
base_model = VGG16(weights='imagenet', include_top=False, input_shape=(256, 256, 3))
for layer in base_model.layers:
    layer.trainable = False

model = Sequential([
    base_model,
    Flatten(),
    Dense(512, activation='relu'),
    BatchNormalization(),
    Dropout(0.5),
    Dense(128, activation='relu'),
    BatchNormalization(),
    Dropout(0.3),
    Dense(len(Class_Names), activation='softmax')
])

model.compile(optimizer=Adam(1e-4), loss='categorical_crossentropy', metrics=['accuracy'])
model.summary()
# Out:
# I0000 00:00:1761286253.738438      37 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13942 MB memory:  -> device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5
# I0000 00:00:1761286253.739168      37 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 13942 MB memory:  -> device: 1, name: Tesla T4, pci bus id: 0000:00:05.0, compute capability: 7.5
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58889256/58889256 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ vgg16 (Functional)              │ (None, 8, 8, 512)      │    14,714,688 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 32768)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 512)            │    16,777,728 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 512)            │         2,048 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 128)            │        65,664 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 128)            │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 5)              │           645 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 31,561,285 (120.40 MB)
#  Trainable params: 16,845,317 (64.26 MB)
#  Non-trainable params: 14,715,968 (56.14 MB)

# %%
checkpoint = ModelCheckpoint('best_model.h5', monitor='val_loss', save_best_only=True, mode='min', verbose=1)
early_stop = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True, verbose=1)
lr_reduce = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=2, verbose=1, min_lr=1e-6)

# %%
history = model.fit(
    train_generator,
    epochs=100,
    validation_data=val_generator,
    callbacks=[checkpoint, early_stop, lr_reduce]
)
# Out:
# Epoch 1/100
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1761286267.791327     107 service.cc:148] XLA service 0x7f37240065c0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1761286267.792399     107 service.cc:156]   StreamExecutor device (0): Tesla T4, Compute Capability 7.5
# I0000 00:00:1761286267.792421     107 service.cc:156]   StreamExecutor device (1): Tesla T4, Compute Capability 7.5
# I0000 00:00:1761286268.447345     107 cuda_dnn.cc:529] Loaded cuDNN version 90300
# 2025-10-24 06:11:15.827593: E external/local_xla/xla/service/slow_operation_alarm.cc:65] Trying algorithm eng12{k11=0} for conv (f32[32,128,128,128]{3,2,1,0}, u8[0]{0}) custom-call(f32[32,128,128,128]{3,2,1,0}, f32[128,128,3,3]{3,2,1,0}, f32[128]{0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"cudnn_conv_backend_config":{"activation_mode":"kRelu","conv_result_scale":1,"leakyrelu_alpha":0,"side_input_scale":0},"force_earliest_schedule":false,"operation_queue_id":"0","wait_on_operation_queues":[]} is taking a while...
# 2025-10-24 06:11:16.049609: E external/local_xla/xla/service/slow_operation_alarm.cc:133] The operation took 1.2221887s
# Trying algorithm eng12{k11=0} for conv (f32[32,128,128,128]{3,2,1,0}, u8[0]{0}) custom-call(f32[32,128,128,128]{3,2,1,0}, f32[128,128,3,3]{3,2,1,0}, f32[128]{0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"cudnn_conv_backend_config":{"activation_mode":"kRelu","conv_result_scale":1,"leakyrelu_alpha":0,"side_input_scale":0},"force_earliest_schedule":false,"operation_queue_id":"0","wait_on_operation_queues":[]} is taking a while...
# I0000 00:00:1761286284.736925     107 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 214/214 ━━━━━━━━━━━━━━━━━━━━ 0s 457ms/step - accuracy: 0.6085 - loss: 1.1181
# Epoch 1: val_loss improved from inf to 0.42528, saving model to best_model.h5
# 214/214 ━━━━━━━━━━━━━━━━━━━━ 144s 577ms/step - accuracy: 0.6089 - loss: 1.1170 - val_accuracy: 0.8560 - val_loss: 0.4253 - learning_rate: 1.0000e-04
# Epoch 2/100
# 214/214 ━━━━━━━━━━━━━━━━━━━━ 0s 407ms/step - accuracy: 0.7967 - loss: 0.5894
# Epoch 2: val_loss did not improve from 0.42528
# 214/214 ━━━━━━━━━━━━━━━━━━━━ 98s 456ms/step - accuracy: 0.7967 - loss: 0.5893 - val_accuracy: 0.8096 - val_loss: 0.4801 - learning_rate: 1.0000e-04
# Epoch 3/100
# 214/214 ━━━━━━━━━━━━━━━━━━━━ 0s 404ms/step - accuracy: 0.8430 - loss: 0.4619
# Epoch 3: val_loss improved from 0.42528 to 0.33135, saving model to best_model.h5
# 214/214 ━━━━━━━━━━━━━━━━━━━━ 98s 457ms/step - accuracy: 0.8430 - loss: 0.4620 - val_accuracy: 0.8771 - val_loss: 0.3314 - learning_rate: 1.0000e-04
# Epoch 4/100
# 214/214 ━━━━━━━━━━━━━━━━━━━━ 0s 419ms/step - accuracy: 0.8380 - loss: 0.4594
# Epoch 4: val_loss improved from 0.33135 to 0.30357, saving model to best_model.h5
# 214/214 ━━━━━━━━━━━━━━━━━━━━ 101s 471ms/step - accuracy: 0.8380 - loss: 0.4593 - val_accuracy: 0.8949 - val_loss: 0.3036 - learning_rate: 1.0000e-04
# Epoch 5/100
# 214/214 ━━━━━━━━━━━━━━━━━━━━ 0s 405ms/step - accuracy: 0.8544 - loss: 0.4075
# Epoch 5: val_loss did not improve from 0.30357
# 214/214 ━━━━━━━━━━━━━━━━━━━━ 97s 453ms/step - accuracy: 0.8544 - loss: 0.4075 - val_accuracy: 0.8280 - val_loss: 0.4927 - learning_rate: 1.0000e-04
# Epoch 6/100
# 214/214 ━━━━━━━━━━━━━━━━━━━━ 0s 405ms/step - accuracy: 0.8707 - loss: 0.3688
# Epoch 6: val_loss improved from 0.30357 to 0.28562, saving model to best_model.h5
# 214/214 ━━━━━━━━━━━━━━━━━━━━ 98s 458ms/step - accuracy: 0.8707 - loss: 0.3689 - val_accuracy: 0.9058 - val_loss: 0.2856 - learning_rate: 1.0000e-04
# Epoch 7/100
# 214/214 ━━━━━━━━━━━━━━━━━━━━ 0s 414ms/step - accuracy: 0.8812 - loss: 0.3352
# Epoch 7: val_loss improved from 0.28562 to 0.24671, saving model to best_model.h5
# 214/214 ━━━━━━━━━━━━━━━━━━━━ 100s 468ms/step - accuracy: 0.8812 - loss: 0.3352 - val_accuracy: 0.9078 - val_loss: 0.2467 - learning_rate: 1.0000e-04
# Epoch 8/100
# 214/214 ━━━━━━━━━━━━━━━━━━━━ 0s 403ms/step - accuracy: 0.8779 - loss: 0.3366
# Epoch 8: val_loss did not improve from 0.24671
# 214/214 ━━━━━━━━━━━━━━━━━━━━ 97s 452ms/step - accuracy: 0.8779 - loss: 0.3366 - val_accuracy: 0.8867 - val_loss: 0.3322 - learning_rate: 1.0000e-04
# Epoch 9/100
# 214/214 ━━━━━━━━━━━━━━━━━━━━ 0s 405ms/step - accuracy: 0.8920 - loss: 0.2951
# Epoch 9: val_loss improved from 0.24671 to 0.21862, saving model to best_model.h5
# 214/214 ━━━━━━━━━━━━━━━━━━━━ 98s 458ms/step - accuracy: 0.8920 - loss: 0.2951 - val_accuracy: 0.9242 - val_loss: 0.2186 - learning_rate: 1.0000e-04
# Epoch 10/100
# 214/214 ━━━━━━━━━━━━━━━━━━━━ 0s 415ms/step - accuracy: 0.8972 - loss: 0.2974
# Epoch 10: val_loss did not improve from 0.21862
# 214/214 ━━━━━━━━━━━━━━━━━━━━ 99s 464ms/step - accuracy: 0.8972 - loss: 0.2974 - val_accuracy: 0.9181 - val_loss: 0.2455 - learning_rate: 1.0000e-04
# Epoch 11/100
# 214/214 ━━━━━━━━━━━━━━━━━━━━ 0s 405ms/step - accuracy: 0.8965 - loss: 0.2948
# Epoch 11: val_loss did not improve from 0.21862
#
# Epoch 11: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# 214/214 ━━━━━━━━━━━━━━━━━━━━ 97s 453ms/step - accuracy: 0.8965 - loss: 0.2948 - val_accuracy: 0.9222 - val_loss: 0.2550 - learning_rate: 1.0000e-04
# Epoch 12/100
# 214/214 ━━━━━━━━━━━━━━━━━━━━ 0s 405ms/step - accuracy: 0.9111 - loss: 0.2561
# Epoch 12: val_loss did not improve from 0.21862
# 214/214 ━━━━━━━━━━━━━━━━━━━━ 97s 454ms/step - accuracy: 0.9111 - loss: 0.2561 - val_accuracy: 0.9201 - val_loss: 0.2312 - learning_rate: 5.0000e-05
# Epoch 13/100
# 214/214 ━━━━━━━━━━━━━━━━━━━━ 0s 420ms/step - accuracy: 0.9135 - loss: 0.2421
# Epoch 13: val_loss did not improve from 0.21862
#
# Epoch 13: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
# 214/214 ━━━━━━━━━━━━━━━━━━━━ 101s 469ms/step - accuracy: 0.9135 - loss: 0.2422 - val_accuracy: 0.9270 - val_loss: 0.2222 - learning_rate: 5.0000e-05
# Epoch 14/100
# 214/214 ━━━━━━━━━━━━━━━━━━━━ 0s 409ms/step - accuracy: 0.9197 - loss: 0.2355
# Epoch 14: val_loss improved from 0.21862 to 0.21144, saving model to best_model.h5
# 214/214 ━━━━━━━━━━━━━━━━━━━━ 99s 462ms/step - accuracy: 0.9197 - loss: 0.2355 - val_accuracy: 0.9297 - val_loss: 0.2114 - learning_rate: 2.5000e-05
# Epoch 15/100
# 214/214 ━━━━━━━━━━━━━━━━━━━━ 0s 410ms/step - accuracy: 0.9161 - loss: 0.2319
# Epoch 15: val_loss improved from 0.21144 to 0.20299, saving model to best_model.h5
# 214/214 ━━━━━━━━━━━━━━━━━━━━ 99s 462ms/step - accuracy: 0.9161 - loss: 0.2319 - val_accuracy: 0.9290 - val_loss: 0.2030 - learning_rate: 2.5000e-05
# Epoch 16/100
# 214/214 ━━━━━━━━━━━━━━━━━━━━ 0s 424ms/step - accuracy: 0.9222 - loss: 0.2160
# Epoch 16: val_loss did not improve from 0.20299
# 214/214 ━━━━━━━━━━━━━━━━━━━━ 101s 473ms/step - accuracy: 0.9222 - loss: 0.2160 - val_accuracy: 0.9290 - val_loss: 0.2096 - learning_rate: 2.5000e-05
# Epoch 17/100
# 214/214 ━━━━━━━━━━━━━━━━━━━━ 0s 402ms/step - accuracy: 0.9218 - loss: 0.2184
# Epoch 17: val_loss improved from 0.20299 to 0.19374, saving model to best_model.h5
# 214/214 ━━━━━━━━━━━━━━━━━━━━ 98s 455ms/step - accuracy: 0.9218 - loss: 0.2184 - val_accuracy: 0.9317 - val_loss: 0.1937 - learning_rate: 2.5000e-05
# Epoch 18/100
# 214/214 ━━━━━━━━━━━━━━━━━━━━ 0s 408ms/step - accuracy: 0.9203 - loss: 0.2111
# Epoch 18: val_loss improved from 0.19374 to 0.19354, saving model to best_model.h5
# 214/214 ━━━━━━━━━━━━━━━━━━━━ 99s 461ms/step - accuracy: 0.9203 - loss: 0.2111 - val_accuracy: 0.9386 - val_loss: 0.1935 - learning_rate: 2.5000e-05
# Epoch 19/100
# 214/214 ━━━━━━━━━━━━━━━━━━━━ 0s 411ms/step - accuracy: 0.9271 - loss: 0.2141
# Epoch 19: val_loss did not improve from 0.19354
# 214/214 ━━━━━━━━━━━━━━━━━━━━ 99s 460ms/step - accuracy: 0.9271 - loss: 0.2141 - val_accuracy: 0.9297 - val_loss: 0.2124 - learning_rate: 2.5000e-05
# Epoch 20/100
# 214/214 ━━━━━━━━━━━━━━━━━━━━ 0s 416ms/step - accuracy: 0.9264 - loss: 0.2100
# Epoch 20: val_loss improved from 0.19354 to 0.18908, saving model to best_model.h5
# 214/214 ━━━━━━━━━━━━━━━━━━━━ 101s 469ms/step - accuracy: 0.9264 - loss: 0.2100 - val_accuracy: 0.9352 - val_loss: 0.1891 - learning_rate: 2.5000e-05
# Epoch 21/100
# 214/214 ━━━━━━━━━━━━━━━━━━━━ 0s 420ms/step - accuracy: 0.9263 - loss: 0.2033
# Epoch 21: val_loss did not improve from 0.18908
# 214/214 ━━━━━━━━━━━━━━━━━━━━ 100s 469ms/step - accuracy: 0.9263 - loss: 0.2033 - val_accuracy: 0.9311 - val_loss: 0.2049 - learning_rate: 2.5000e-05
# Epoch 22/100
# 214/214 ━━━━━━━━━━━━━━━━━━━━ 0s 406ms/step - accuracy: 0.9209 - loss: 0.2122
# Epoch 22: val_loss did not improve from 0.18908
#
# Epoch 22: ReduceLROnPlateau reducing learning rate to 1.249999968422344e-05.
# 214/214 ━━━━━━━━━━━━━━━━━━━━ 97s 454ms/step - accuracy: 0.9209 - loss: 0.2121 - val_accuracy: 0.9365 - val_loss: 0.1911 - learning_rate: 2.5000e-05
# Epoch 23/100
# 214/214 ━━━━━━━━━━━━━━━━━━━━ 0s 414ms/step - accuracy: 0.9360 - loss: 0.1866
# Epoch 23: val_loss did not improve from 0.18908
# 214/214 ━━━━━━━━━━━━━━━━━━━━ 99s 462ms/step - accuracy: 0.9360 - loss: 0.1866 - val_accuracy: 0.9372 - val_loss: 0.1907 - learning_rate: 1.2500e-05
# Epoch 24/100
# 214/214 ━━━━━━━━━━━━━━━━━━━━ 0s 413ms/step - accuracy: 0.9329 - loss: 0.1917
# Epoch 24: val_loss did not improve from 0.18908
#
# Epoch 24: ReduceLROnPlateau reducing learning rate to 6.24999984211172e-06.
# 214/214 ━━━━━━━━━━━━━━━━━━━━ 99s 461ms/step - accuracy: 0.9329 - loss: 0.1917 - val_accuracy: 0.9345 - val_loss: 0.1928 - learning_rate: 1.2500e-05
# Epoch 25/100
# 214/214 ━━━━━━━━━━━━━━━━━━━━ 0s 415ms/step - accuracy: 0.9319 - loss: 0.1987
# Epoch 25: val_loss improved from 0.18908 to 0.18440, saving model to best_model.h5
# 214/214 ━━━━━━━━━━━━━━━━━━━━ 100s 467ms/step - accuracy: 0.9319 - loss: 0.1987 - val_accuracy: 0.9365 - val_loss: 0.1844 - learning_rate: 6.2500e-06
# Epoch 26/100
# 214/214 ━━━━━━━━━━━━━━━━━━━━ 0s 405ms/step - accuracy: 0.9335 - loss: 0.1969
# Epoch 26: val_loss improved from 0.18440 to 0.18405, saving model to best_model.h5
# 214/214 ━━━━━━━━━━━━━━━━━━━━ 98s 459ms/step - accuracy: 0.9335 - loss: 0.1968 - val_accuracy: 0.9413 - val_loss: 0.1840 - learning_rate: 6.2500e-06
# Epoch 27/100
# 214/214 ━━━━━━━━━━━━━━━━━━━━ 0s 464ms/step - accuracy: 0.9396 - loss: 0.1647
# Epoch 27: val_loss did not improve from 0.18405
# 214/214 ━━━━━━━━━━━━━━━━━━━━ 110s 513ms/step - accuracy: 0.9396 - loss: 0.1647 - val_accuracy: 0.9392 - val_loss: 0.1854 - learning_rate: 6.2500e-06
# Epoch 28/100
# 214/214 ━━━━━━━━━━━━━━━━━━━━ 0s 475ms/step - accuracy: 0.9373 - loss: 0.1783
# Epoch 28: val_loss did not improve from 0.18405
#
# Epoch 28: ReduceLROnPlateau reducing learning rate to 3.12499992105586e-06.
# 214/214 ━━━━━━━━━━━━━━━━━━━━ 112s 524ms/step - accuracy: 0.9373 - loss: 0.1783 - val_accuracy: 0.9392 - val_loss: 0.1865 - learning_rate: 6.2500e-06
# Epoch 29/100
# 214/214 ━━━━━━━━━━━━━━━━━━━━ 0s 467ms/step - accuracy: 0.9384 - loss: 0.1827
# Epoch 29: val_loss did not improve from 0.18405
# 214/214 ━━━━━━━━━━━━━━━━━━━━ 110s 516ms/step - accuracy: 0.9384 - loss: 0.1827 - val_accuracy: 0.9386 - val_loss: 0.1863 - learning_rate: 3.1250e-06
# Epoch 30/100
# 214/214 ━━━━━━━━━━━━━━━━━━━━ 0s 432ms/step - accuracy: 0.9413 - loss: 0.1743
# Epoch 30: val_loss did not improve from 0.18405
#
# Epoch 30: ReduceLROnPlateau reducing learning rate to 1.56249996052793e-06.
# 214/214 ━━━━━━━━━━━━━━━━━━━━ 103s 480ms/step - accuracy: 0.9412 - loss: 0.1743 - val_accuracy: 0.9372 - val_loss: 0.1901 - learning_rate: 3.1250e-06
# Epoch 31/100
# 214/214 ━━━━━━━━━━━━━━━━━━━━ 0s 437ms/step - accuracy: 0.9366 - loss: 0.1749
# Epoch 31: val_loss did not improve from 0.18405
# 214/214 ━━━━━━━━━━━━━━━━━━━━ 104s 485ms/step - accuracy: 0.9366 - loss: 0.1749 - val_accuracy: 0.9386 - val_loss: 0.1880 - learning_rate: 1.5625e-06
# Epoch 32/100
# 214/214 ━━━━━━━━━━━━━━━━━━━━ 0s 440ms/step - accuracy: 0.9365 - loss: 0.1764
# Epoch 32: val_loss did not improve from 0.18405
#
# Epoch 32: ReduceLROnPlateau reducing learning rate to 1e-06.
# 214/214 ━━━━━━━━━━━━━━━━━━━━ 105s 488ms/step - accuracy: 0.9365 - loss: 0.1764 - val_accuracy: 0.9365 - val_loss: 0.1874 - learning_rate: 1.5625e-06
# Epoch 33/100
# 214/214 ━━━━━━━━━━━━━━━━━━━━ 0s 431ms/step - accuracy: 0.9401 - loss: 0.1689
# Epoch 33: val_loss did not improve from 0.18405
# 214/214 ━━━━━━━━━━━━━━━━━━━━ 103s 479ms/step - accuracy: 0.9401 - loss: 0.1689 - val_accuracy: 0.9358 - val_loss: 0.1882 - learning_rate: 1.0000e-06
# Epoch 34/100
# 214/214 ━━━━━━━━━━━━━━━━━━━━ 0s 448ms/step - accuracy: 0.9386 - loss: 0.1763
# Epoch 34: val_loss did not improve from 0.18405
# 214/214 ━━━━━━━━━━━━━━━━━━━━ 106s 497ms/step - accuracy: 0.9386 - loss: 0.1763 - val_accuracy: 0.9365 - val_loss: 0.1870 - learning_rate: 1.0000e-06
# Epoch 35/100
# 214/214 ━━━━━━━━━━━━━━━━━━━━ 0s 449ms/step - accuracy: 0.9412 - loss: 0.1767
# Epoch 35: val_loss did not improve from 0.18405
# 214/214 ━━━━━━━━━━━━━━━━━━━━ 107s 498ms/step - accuracy: 0.9412 - loss: 0.1767 - val_accuracy: 0.9372 - val_loss: 0.1867 - learning_rate: 1.0000e-06
# Epoch 36/100
# 214/214 ━━━━━━━━━━━━━━━━━━━━ 0s 443ms/step - accuracy: 0.9377 - loss: 0.1726
# Epoch 36: val_loss did not improve from 0.18405
# 214/214 ━━━━━━━━━━━━━━━━━━━━ 105s 491ms/step - accuracy: 0.9377 - loss: 0.1726 - val_accuracy: 0.9392 - val_loss: 0.1846 - learning_rate: 1.0000e-06
# Epoch 36: early stopping
# Restoring model weights from the end of the best epoch: 26.

# %%
test_loss, test_acc = model.evaluate(test_generator)
print(f"\n Test Accuracy: {test_acc*100:.2f}%")
print(f" Test Loss: {test_loss:.4f}")
# Out:
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 24s 516ms/step - accuracy: 0.9435 - loss: 0.1697
#
#  Test Accuracy: 94.75%
#  Test Loss: 0.1630

# %%
y_pred_probs = model.predict(test_generator)
y_pred = np.argmax(y_pred_probs, axis=1)
y_true = np.argmax(Test_Labels_cat, axis=1)
class_labels = Class_Names

print("\n Classification Report:")
print(classification_report(y_true, y_pred, target_names=class_labels))

cm = confusion_matrix(y_true, y_pred)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=class_labels)

plt.figure(figsize=(8,6))
disp.plot(cmap='Blues', values_format='d')
plt.title("Confusion Matrix - VGG16 Model")
plt.show()
# Out:
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 12s 244ms/step
#
#  Classification Report:
#               precision    recall  f1-score   support
#
#         acne       0.90      0.95      0.92       309
#   dark spots       0.94      0.94      0.94       319
#     wrinkles       0.97      0.97      0.97       298
#        pores       0.97      0.98      0.98       244
#  blackheades       0.96      0.90      0.93       296
#
#     accuracy                           0.95      1466
#    macro avg       0.95      0.95      0.95      1466
# weighted avg       0.95      0.95      0.95      1466

# %% [markdown]
# **Resnet_model**

# %%
from tensorflow.keras.applications import ResNet50
from tensorflow.keras.models import Model
from tensorflow.keras.layers import GlobalAveragePooling2D, Dense, Dropout
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.models import Sequential

# %%
pretrained_model= tf.keras.applications.ResNet50(include_top=False,
                    input_shape=(256, 256, 3) ,
                   pooling='avg',classes=5,
                   weights='imagenet')

for layer in pretrained_model.layers:  
    layer.trainable = True

resnet_model = Sequential([
    pretrained_model,
    Flatten(),
    Dense(512, activation='relu'),
    Dropout(0.5),
    Dense(5, activation='softmax')
])


resnet_model.summary()
# Out:
# Model: "sequential_3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ resnet50 (Functional)           │ (None, 2048)           │    23,587,712 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_3 (Flatten)             │ (None, 2048)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_7 (Dense)                 │ (None, 512)            │     1,049,088 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_8 (Dense)                 │ (None, 5)              │         2,565 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 24,639,365 (93.99 MB)
#  Trainable params: 24,586,245 (93.79 MB)
#  Non-trainable params: 53,120 (207.50 KB)

# %%
from tensorflow.keras.optimizers import Adam

resnet_model.compile(
    optimizer=Adam(learning_rate=0.001),   
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

# %%
history = resnet_model.fit(
    train_generator,
    validation_data=val_generator,
    epochs=100,
    callbacks=[early_stop]
)
# Out:
# Epoch 1/100
# 214/214 ━━━━━━━━━━━━━━━━━━━━ 183s 553ms/step - accuracy: 0.6379 - loss: 1.1721 - val_accuracy: 0.2027 - val_loss: 4.3420
# Epoch 2/100
# 214/214 ━━━━━━━━━━━━━━━━━━━━ 94s 435ms/step - accuracy: 0.8303 - loss: 0.5073 - val_accuracy: 0.2109 - val_loss: 2.8198
# Epoch 3/100
# 214/214 ━━━━━━━━━━━━━━━━━━━━ 101s 472ms/step - accuracy: 0.8740 - loss: 0.3896 - val_accuracy: 0.3031 - val_loss: 1.5683
# Epoch 4/100
# 214/214 ━━━━━━━━━━━━━━━━━━━━ 97s 451ms/step - accuracy: 0.8959 - loss: 0.3147 - val_accuracy: 0.2553 - val_loss: 4.7409
# Epoch 5/100
# 214/214 ━━━━━━━━━━━━━━━━━━━━ 97s 450ms/step - accuracy: 0.8980 - loss: 0.3091 - val_accuracy: 0.4614 - val_loss: 1.8031
# Epoch 6/100
# 214/214 ━━━━━━━━━━━━━━━━━━━━ 95s 440ms/step - accuracy: 0.9078 - loss: 0.2724 - val_accuracy: 0.7631 - val_loss: 1.2204
# Epoch 7/100
# 214/214 ━━━━━━━━━━━━━━━━━━━━ 97s 450ms/step - accuracy: 0.9201 - loss: 0.2450 - val_accuracy: 0.6478 - val_loss: 1.1180
# Epoch 8/100
# 214/214 ━━━━━━━━━━━━━━━━━━━━ 95s 443ms/step - accuracy: 0.9215 - loss: 0.2256 - val_accuracy: 0.5188 - val_loss: 2.9133
# Epoch 9/100
# 214/214 ━━━━━━━━━━━━━━━━━━━━ 98s 456ms/step - accuracy: 0.9242 - loss: 0.2424 - val_accuracy: 0.5829 - val_loss: 2.5823
# Epoch 10/100
# 214/214 ━━━━━━━━━━━━━━━━━━━━ 95s 441ms/step - accuracy: 0.9218 - loss: 0.2266 - val_accuracy: 0.7427 - val_loss: 0.9525
# Epoch 11/100
# 214/214 ━━━━━━━━━━━━━━━━━━━━ 95s 442ms/step - accuracy: 0.9490 - loss: 0.1646 - val_accuracy: 0.6867 - val_loss: 1.2761
# Epoch 12/100
# 214/214 ━━━━━━━━━━━━━━━━━━━━ 97s 450ms/step - accuracy: 0.9366 - loss: 0.1822 - val_accuracy: 0.7427 - val_loss: 0.7496
# Epoch 13/100
# 214/214 ━━━━━━━━━━━━━━━━━━━━ 99s 460ms/step - accuracy: 0.9487 - loss: 0.1618 - val_accuracy: 0.8253 - val_loss: 0.5476
# Epoch 14/100
# 214/214 ━━━━━━━━━━━━━━━━━━━━ 96s 448ms/step - accuracy: 0.9408 - loss: 0.1763 - val_accuracy: 0.7276 - val_loss: 1.0775
# Epoch 15/100
# 214/214 ━━━━━━━━━━━━━━━━━━━━ 98s 455ms/step - accuracy: 0.9512 - loss: 0.1426 - val_accuracy: 0.8724 - val_loss: 0.3957
# Epoch 16/100
# 214/214 ━━━━━━━━━━━━━━━━━━━━ 98s 457ms/step - accuracy: 0.9467 - loss: 0.1594 - val_accuracy: 0.8457 - val_loss: 0.6799
# Epoch 17/100
# 214/214 ━━━━━━━━━━━━━━━━━━━━ 96s 446ms/step - accuracy: 0.9470 - loss: 0.1504 - val_accuracy: 0.7515 - val_loss: 0.9888
# Epoch 18/100
# 214/214 ━━━━━━━━━━━━━━━━━━━━ 95s 445ms/step - accuracy: 0.9624 - loss: 0.1126 - val_accuracy: 0.4922 - val_loss: 8.4298
# Epoch 19/100
# 214/214 ━━━━━━━━━━━━━━━━━━━━ 100s 464ms/step - accuracy: 0.9457 - loss: 0.1541 - val_accuracy: 0.8423 - val_loss: 0.5637
# Epoch 20/100
# 214/214 ━━━━━━━━━━━━━━━━━━━━ 96s 449ms/step - accuracy: 0.9612 - loss: 0.1196 - val_accuracy: 0.6717 - val_loss: 1.4893
# Epoch 21/100
# 214/214 ━━━━━━━━━━━━━━━━━━━━ 97s 454ms/step - accuracy: 0.9616 - loss: 0.1100 - val_accuracy: 0.8451 - val_loss: 0.6570
# Epoch 22/100
# 214/214 ━━━━━━━━━━━━━━━━━━━━ 99s 462ms/step - accuracy: 0.9596 - loss: 0.1231 - val_accuracy: 0.7208 - val_loss: 1.2416
# Epoch 23/100
# 214/214 ━━━━━━━━━━━━━━━━━━━━ 101s 471ms/step - accuracy: 0.9588 - loss: 0.1230 - val_accuracy: 0.7392 - val_loss: 1.2939
# Epoch 24/100
# 214/214 ━━━━━━━━━━━━━━━━━━━━ 96s 448ms/step - accuracy: 0.9537 - loss: 0.1340 - val_accuracy: 0.5761 - val_loss: 2.7492
# Epoch 25/100
# 214/214 ━━━━━━━━━━━━━━━━━━━━ 102s 474ms/step - accuracy: 0.9633 - loss: 0.1089 - val_accuracy: 0.8860 - val_loss: 0.3542
# Epoch 26/100
# 214/214 ━━━━━━━━━━━━━━━━━━━━ 101s 472ms/step - accuracy: 0.9644 - loss: 0.1029 - val_accuracy: 0.8997 - val_loss: 0.3370
# Epoch 27/100
# 214/214 ━━━━━━━━━━━━━━━━━━━━ 96s 445ms/step - accuracy: 0.9662 - loss: 0.0895 - val_accuracy: 0.7563 - val_loss: 0.8599
# Epoch 28/100
# 214/214 ━━━━━━━━━━━━━━━━━━━━ 98s 458ms/step - accuracy: 0.9565 - loss: 0.1201 - val_accuracy: 0.9399 - val_loss: 0.2104
# Epoch 29/100
# 214/214 ━━━━━━━━━━━━━━━━━━━━ 100s 468ms/step - accuracy: 0.9713 - loss: 0.0868 - val_accuracy: 0.5358 - val_loss: 2.3463
# Epoch 30/100
# 214/214 ━━━━━━━━━━━━━━━━━━━━ 97s 453ms/step - accuracy: 0.9702 - loss: 0.0850 - val_accuracy: 0.8157 - val_loss: 0.7766
# Epoch 31/100
# 214/214 ━━━━━━━━━━━━━━━━━━━━ 97s 454ms/step - accuracy: 0.9708 - loss: 0.0852 - val_accuracy: 0.5918 - val_loss: 2.2774
# Epoch 32/100
# 214/214 ━━━━━━━━━━━━━━━━━━━━ 101s 470ms/step - accuracy: 0.9693 - loss: 0.0939 - val_accuracy: 0.8253 - val_loss: 0.8072
# Epoch 33/100
# 214/214 ━━━━━━━━━━━━━━━━━━━━ 94s 437ms/step - accuracy: 0.9671 - loss: 0.1033 - val_accuracy: 0.7666 - val_loss: 1.1022
# Epoch 34/100
# 214/214 ━━━━━━━━━━━━━━━━━━━━ 95s 444ms/step - accuracy: 0.9730 - loss: 0.0817 - val_accuracy: 0.7454 - val_loss: 1.0417
# Epoch 35/100
# 214/214 ━━━━━━━━━━━━━━━━━━━━ 98s 454ms/step - accuracy: 0.9722 - loss: 0.0863 - val_accuracy: 0.6184 - val_loss: 1.9792
# Epoch 36/100
# 214/214 ━━━━━━━━━━━━━━━━━━━━ 97s 453ms/step - accuracy: 0.9695 - loss: 0.0960 - val_accuracy: 0.8853 - val_loss: 0.5307
# Epoch 37/100
# 214/214 ━━━━━━━━━━━━━━━━━━━━ 97s 452ms/step - accuracy: 0.9686 - loss: 0.0981 - val_accuracy: 0.7468 - val_loss: 1.0463
# Epoch 38/100
# 214/214 ━━━━━━━━━━━━━━━━━━━━ 98s 458ms/step - accuracy: 0.9687 - loss: 0.0935 - val_accuracy: 0.8662 - val_loss: 0.5337
# Epoch 38: early stopping
# Restoring model weights from the end of the best epoch: 28.

# %%
test_loss, test_acc = resnet_model.evaluate(test_generator)
print(f"Test Accuracy: {test_acc:.4f}")
# Out:
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 6s 131ms/step - accuracy: 0.9398 - loss: 0.1887
# Test Accuracy: 0.9400

# %%
y_pred_probs = resnet_model.predict(test_generator)
y_pred = np.argmax(y_pred_probs, axis=1)
y_true = np.argmax(Test_Labels_cat, axis=1)
class_labels = Class_Names

print("\n Classification Report:")
print(classification_report(y_true, y_pred, target_names=class_labels))

cm = confusion_matrix(y_true, y_pred)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=class_labels)

plt.figure(figsize=(8,6))
disp.plot(cmap='Blues', values_format='d')
plt.title("Confusion Matrix - ResNET Model")
plt.show()
# Out:
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 15s 232ms/step
#
#  Classification Report:
#               precision    recall  f1-score   support
#
#         acne       0.94      0.93      0.93       309
#   dark spots       0.94      0.93      0.94       319
#     wrinkles       0.92      0.99      0.95       298
#        pores       0.94      1.00      0.97       244
#  blackheades       0.97      0.86      0.91       296
#
#     accuracy                           0.94      1466
#    macro avg       0.94      0.94      0.94      1466
# weighted avg       0.94      0.94      0.94      1466
